# %%
# set directories
inputpath=r'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/raw'
outputpath=r'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output'

# %%
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: pandas in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\buca4591\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# packages
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
import os
import shutil
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import string  
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from tqdm import tnrange, tqdm_notebook
from itertools import combinations
import seaborn as sns
from sklearn.linear_model import Ridge,Lasso
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.cross_decomposition import PLSRegression
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import math
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
# Define the URL of the Numbeo page you want to scrape
url = 'https://www.numbeo.com/cost-of-living/rankings_by_country.jsp'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the table containing cost of living data
    table = soup.find('table', {'id': 't2'})

    # Create empty lists to store data
    categories = []
    prices_usd = []
    countries = []
    cost_of_living_relative = []

    # Iterate through rows in the table
    for row in table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        categories.append(columns[1].text.strip())
        prices_usd.append(columns[2].text.strip())
        countries.append(columns[0].text.strip())
        cost_of_living_relative.append(columns[3].text.strip())

    # Create a DataFrame to store the data
    data = {
        'Country': countries,
        'Product Category': categories,
        'Price (USD)': prices_usd,
        'Cost of Living Relative to US': cost_of_living_relative
    }
    df = pd.DataFrame(data)

    # Save the data to a CSV file
    file_path = os.path.join(outputpath, 'cost_of_living.csv')
    df.to_csv(file_path, index=False)

    print("Data has been scraped and saved to 'cost_of_living.csv'.")

else:
    print("Failed to retrieve data from the website.")
# Out:
# Data has been scraped and saved to 'cost_of_living.csv'.

# %%
# Define the URL of the Numbeo page you want to scrape
url = 'https://www.numbeo.com/cost-of-living/rankings_by_country.jsp'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the table containing cost of living data
    table = soup.find('table', {'id': 't2'})

    # Create empty lists to store data
    categories = []
    prices_usd = []
    countries = []
    cost_of_living_relative = []

    # Iterate through rows in the table
    for row in table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        categories.append(columns[1].text.strip())
        prices_usd.append(columns[2].text.strip())
        countries.append(columns[0].text.strip())
        cost_of_living_relative.append(columns[3].text.strip())

    # Create a DataFrame to store the data
    data = {
        'Country': countries,
        'Product Category': categories,
        'Price (USD)': prices_usd,
        'Cost of Living Relative to US': cost_of_living_relative
    }
    df = pd.DataFrame(data)

    # Save the data to a CSV file in the specified folder
    csv_file_path = os.path.join(outputpath, 'cost_of_living.csv')
    df.to_csv(csv_file_path, index=False)

    print(f"Data has been scraped and saved to '{csv_file_path}'.")

    # Download and save the page as .html
    html_url = 'https://www.numbeo.com/cost-of-living/'
    html_response = requests.get(html_url)
    if html_response.status_code == 200:
        html_file_path = os.path.join(outputpath, 'numbeo_cost_of_living.html')
        with open(html_file_path, 'w', encoding='utf-8') as html_file:
            html_file.write(html_response.text)
        print(f"Numbeo cost of living page saved as '{html_file_path}'.")

        # Iterate over all countries
        for country_name in countries:
            # Handle country names with spaces by replacing with hyphens and making the URL
            country_url = f'https://www.numbeo.com/cost-of-living/country_result.jsp?country={country_name.replace(" ", "-")}&displayCurrency=USD'

            country_response = requests.get(country_url)
            if country_response.status_code == 200:
                # Load the country HTML file into a BeautifulSoup object
                country_soup = BeautifulSoup(country_response.content, 'html.parser')

                # Find the relevant table
                country_table = country_soup.find('table', {'id': 't2'})

                # Extract the cost of living relative to Sweden using regular expressions
                sweden_relative_cost = re.search(r'Cost of Living in Sweden: ([0-9.]+)%', country_soup.text)
                if sweden_relative_cost:
                    sweden_relative_cost = sweden_relative_cost.group(1)
                else:
                    sweden_relative_cost = 'N/A'

                # Print the table headings, values, and Sweden's cost of living relative
                output_file_path = os.path.join(outputpath, f'{country_name.replace(" ", "_")}_data.txt')
                with open(output_file_path, 'w', encoding='utf-8') as output_file:
                    output_file.write("Table Headings: ")
                    output_file.write(','.join(categories) + '\n')
                    output_file.write("Table Values: ")
                    output_file.write(','.join(prices_usd) + '\n')
                    output_file.write(f"Cost of Living Relative to Sweden: {sweden_relative_cost}%")

                print(f"Country data for '{country_name}' has been saved to '{output_file_path}'.")

            else:
                print(f"Failed to download the country HTML file for '{country_name}'.")

    else:
        print("Failed to download the HTML page.")

else:
    print("Failed to retrieve data from the website.")
# Out:
# Data has been scraped and saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\cost_of_living.csv'.
# Numbeo cost of living page saved as 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\numbeo_cost_of_living.html'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.
# Country data for '' has been saved to 'C:/Users/buca4591/Desktop/GIT/Applied_Empirical/task9/analysis/output\_data.txt'.

# %%
# Initialize an empty list to store DataFrames
dataframes = []

# Iterate over files in the directory
for filename in os.listdir(outputpath):
    if filename.endswith('.txt'):
        # Construct the full path to the text file
        file_path = os.path.join(outputpath, filename)

        # Read the text file into a DataFrame
        df = pd.read_csv(file_path, sep=',')
        
        # Add the country name to the DataFrame
        country_name = filename.replace('_data.txt', '').replace('_', ' ')
        df['Country'] = country_name

        dataframes.append(df)

# Concatenate all DataFrames into one
combined_df = pd.concat(dataframes, ignore_index=True)

# Convert the combined DataFrame to a Stata .dta file
stata_file_path = 'outputpath/all_countries_data.dta'  

combined_df.to_stata(stata_file_path, write_index=False)

print(f"Data has been combined and saved to '{stata_file_path}' as a Stata dataset.")
# Out:
# C:\Users\buca4591\AppData\Local\Temp\ipykernel_6632\1999969268.py:25: InvalidColumnName:
# Not all pandas column names were valid Stata variable names.
# The following replacements have been made:
#
#     Table Headings: Bermuda   ->   Table_Headings__Bermuda
#     Cayman Islands   ->   Cayman_Islands
#     United States   ->   United_States
#     Hong Kong (China)   ->   Hong_Kong__China_
#     New Zealand   ->   New_Zealand
#     South Korea   ->   South_Korea
#     Puerto Rico   ->   Puerto_Rico
#     Macao (China)   ->   Macao__China_
#     United Kingdom   ->   United_Kingdom
#     Isle Of Man   ->   Isle_Of_Man
#     United Arab Emirates   ->   United_Arab_Emirates
#     Trinidad And Tobago   ->   Trinidad_And_Tobago
#     Costa Rica   ->   Costa_Rica
#     Czech Republic   ->   Czech_Republic
#     Saudi Arabia   ->   Saudi_Arabia
#     Ivory Coast   ->   Ivory_Coast
#     Dominican Republic   ->   Dominican_Republic
#     El Salvador   ->   El_Salvador
#     Bosnia And Herzegovina   ->   Bosnia_And_Herzegovina
#     South Africa   ->   South_Africa
#     Sri Lanka   ->   Sri_Lanka
#     North Macedonia   ->   North_Macedonia
#     Kosovo (Disputed Territory)   ->   Kosovo__Disputed_Territory_
#
# If this is not what you expect, please make sure you have Stata-compliant
# column names in your DataFrame (strings only, max 32 characters, only
# alphanumerics and underscores, no Stata reserved words)
#
#   combined_df.to_stata(stata_file_path, write_index=False)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[47], line 25
#      22 # Convert the combined DataFrame to a Stata .dta file
#      23 stata_file_path = 'outputpath/all_countries_data.dta'
# ---> 25 combined_df.to_stata(stata_file_path, write_index=False)
#      27 print(f"Data has been combined and saved to '{stata_file_path}' as a Stata dataset.")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:2766, in DataFrame.to_stata(self, path, convert_dates, write_index, byteorder, time_stamp, data_label, variable_labels, version, convert_strl, compression, storage_options, value_labels)
#    2750     kwargs["version"] = version
#    2752 writer = statawriter(
#    2753     path,
#    2754     self,
#    (...)
#    2764     **kwargs,
#    2765 )
# -> 2766 writer.write_file()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\stata.py:2632, in StataWriter.write_file(self)
#    2628 def write_file(self) -> None:
#    2629     """
#    2630     Export DataFrame object to Stata dta format.
#    2631     """
# -> 2632     with get_handle(
#    2633         self._fname,
#    2634         "wb",
#    2635         compression=self._compression,
#    2636         is_text=False,
#    2637         storage_options=self.storage_options,
#    2638     ) as self.handles:
#    2640         if self.handles.compression["method"] is not None:
#    2641             # ZipFile creates a file (with the same name) for each write call.
#    2642             # Write it first into a buffer and then write the buffer to the ZipFile.
#    2643             self._output_file, self.handles.handle = self.handles.handle, BytesIO()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'outputpath'
